# %%
# !pip install cryptocompare
# Out:
# Requirement already satisfied: cryptocompare in /usr/local/lib/python3.10/dist-packages (0.7.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from cryptocompare) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->cryptocompare) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->cryptocompare) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->cryptocompare) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->cryptocompare) (3.4)

# %%
from google.colab import drive, files
import pandas as pd
import numpy as np
import cryptocompare
import joblib
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.utils import plot_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import math
import xgboost as xgb
import datetime
from sklearn.preprocessing import MinMaxScaler
from itertools import cycle
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# coin = 'BTC'
# currency = 'USD'
# limit = 1000
# data = cryptocompare.get_historical_price_day(coin, currency, limit=limit)
# df = pd.DataFrame(data)
# df['time'] = pd.to_datetime(df['time'], unit='s')
# print(df)

# %%
# df = pd.DataFrame({"date": df['time'], "close": df["close"]})
# df.to_csv("BTC_USD_close_price_history.csv")
# files.download("BTC_USD_close_price_history.csv")

# %%
df = pd.read_csv("/content/drive/MyDrive/Project II/BTC_USD_close_price_history.csv")

# %%
fig = px.line(df, x = 'date', y = 'close')
fig.update_layout(title_text = "1001 days bitcoin close price up to now")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="12fb651c-575e-4005-96fb-101b116eecac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12fb651c-575e-4005-96fb-101b116eecac")) {                    Plotly.newPlot(                        "12fb651c-575e-4005-96fb-101b116eecac",                        [{"hovertemplate":"date=%{x}<br>close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-10","2020-10-11","2020-10-12","2020-10-13","2020-10-14","2020-10-15","2020-10-16","2020-10-17","2020-10-18","2020-10-19","2020-10-20","2020-10-21","2020-10-22","2020-10-23","2020-10-24","2020-10-25","2020-10-26","2020-10-27","2020-10-28","2020-10-29","2020-10-30","2020-10-31","2020-11-01","2020-11-02","2020-11-03","2020-11-04","2020-11-05","2020-11-06","2020-11-07","2020-11-08","2020-11-09","2020-11-10","2020-11-11","2020-11-12","2020-11-13","2020-11-14","2020-11-15","2020-11-16","2020-11-17","2020-11-18","2020-11-19","2020-11-20","2020-11-21","2020-11-22","2020-11-23","2020-11-24","2020-11-25","2020-11-26","2020-11-27","2020-11-28","2020-11-29","2020-11-30","2020-12-01","2020-12-02","2020-12-03","2020-12-04","2020-12-05","2020-12-06","2020-12-07","2020-12-08","2020-12-09","2020-12-10","2020-12-11","2020-12-12","2020-12-13","2020-12-14","2020-12-15","2020-12-16","2020-12-17","2020-12-18","2020-12-19","2020-12-20","2020-12-21","2020-12-22","2020-12-23","2020-12-24","2020-12-25","2020-12-26","2020-12-27","2020-12-28","2020-12-29","2020-12-30","2020-12-31","2021-01-01","2021-01-02","2021-01-03","2021-01-04","2021-01-05","2021-01-06","2021-01-07","2021-01-08","2021-01-09","2021-01-10","2021-01-11","2021-01-12","2021-01-13","2021-01-14","2021-01-15","2021-01-16","2021-01-17","2021-01-18","2021-01-19","2021-01-20","2021-01-21","2021-01-22","2021-01-23","2021-01-24","2021-01-25","2021-01-26","2021-01-27","2021-01-28","2021-01-29","2021-01-30","2021-01-31","2021-02-01","2021-02-02","2021-02-03","2021-02-04","2021-02-05","2021-02-06","2021-02-07","2021-02-08","2021-02-09","2021-02-10","2021-02-11","2021-02-12","2021-02-13","2021-02-14","2021-02-15","2021-02-16","2021-02-17","2021-02-18","2021-02-19","2021-02-20","2021-02-21","2021-02-22","2021-02-23","2021-02-24","2021-02-25","2021-02-26","2021-02-27","2021-02-28","2021-03-01","2021-03-02","2021-03-03","2021-03-04","2021-03-05","2021-03-06","2021-03-07","2021-03-08","2021-03-09","2021-03-10","2021-03-11","2021-03-12","2021-03-13","2021-03-14","2021-03-15","2021-03-16","2021-03-17","2021-03-18","2021-03-19","2021-03-20","2021-03-21","2021-03-22","2021-03-23","2021-03-24","2021-03-25","2021-03-26","2021-03-27","2021-03-28","2021-03-29","2021-03-30","2021-03-31","2021-04-01","2021-04-02","2021-04-03","2021-04-04","2021-04-05","2021-04-06","2021-04-07","2021-04-08","2021-04-09","2021-04-10","2021-04-11","2021-04-12","2021-04-13","2021-04-14","2021-04-15","2021-04-16","2021-04-17","2021-04-18","2021-04-19","2021-04-20","2021-04-21","2021-04-22","2021-04-23","2021-04-24","2021-04-25","2021-04-26","2021-04-27","2021-04-28","2021-04-29","2021-04-30","2021-05-01","2021-05-02","2021-05-03","2021-05-04","2021-05-05","2021-05-06","2021-05-07","2021-05-08","2021-05-09","2021-05-10","2021-05-11","2021-05-12","2021-05-13","2021-05-14","2021-05-15","2021-05-16","2021-05-17","2021-05-18","2021-05-19","2021-05-20","2021-05-21","2021-05-22","2021-05-23","2021-05-24","2021-05-25","2021-05-26","2021-05-27","2021-05-28","2021-05-29","2021-05-30","2021-05-31","2021-06-01","2021-06-02","2021-06-03","2021-06-04","2021-06-05","2021-06-06","2021-06-07","2021-06-08","2021-06-09","2021-06-10","2021-06-11","2021-0 ...

# %%
print('Total number of days present in the dataset: ',df.shape[0])
print('Total number of fields present in the dataset: ',df.shape[1])
# Out:
# Total number of days present in the dataset:  1001
# Total number of fields present in the dataset:  3

# %%
df.shape
# Out:
# (1001, 3)

# %%
df.head()
# Out:
#    Unnamed: 0        date     close
# 0           0  2020-10-05  10795.11
# 1           1  2020-10-06  10603.90
# 2           2  2020-10-07  10672.67
# 3           3  2020-10-08  10929.40
# 4           4  2020-10-09  11058.78

# %%
df.tail()
# Out:
#       Unnamed: 0        date     close
# 996          996  2023-06-28  30080.24
# 997          997  2023-06-29  30446.53
# 998          998  2023-06-30  30471.00
# 999          999  2023-07-01  30590.71
# 1000        1000  2023-07-02  30534.32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1001 non-null   int64
#  1   date        1001 non-null   object
#  2   close       1001 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.6+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0         close
# count  1001.000000   1001.000000
# mean    500.000000  33744.518911
# std     289.108111  13895.917416
# min       0.000000  10603.900000
# 25%     250.000000  21352.130000
# 50%     500.000000  30534.320000
# 75%     750.000000  44425.520000
# max    1000.000000  67549.140000

# %%
print('Null Values: ',df.isnull().values.sum())
# Out:
# Null Values:  0

# %%
def split(data, ratio):
    '''
        Input: data: pandas DataFrame
               ratio: list of 3 numbers that correspond to the ratio train:val:test
        Output: train, val, test
    '''
    train_size = int(len(data) * ratio[0])
    val_size = int(len(data) * ratio[1])
    test_size = len(data) - train_size - val_size
    return data[:train_size, :], data[train_size:train_size + val_size, :], data[train_size + val_size:, :]

# %%
#data only contains the close price
data = np.array(df["close"]).reshape(-1, 1)

# %%
train_data, val_data, test_data = split(data, [0.6, 0.2, 0.2])

# %%
scaler = MinMaxScaler()
train_data = scaler.fit_transform(train_data)
val_data = scaler.transform(val_data)
test_data = scaler.transform(test_data)

# %%
joblib.dump(scaler, 'scaler.save')
# Out:
# ['scaler.save']

# %%
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i : ( i + time_step ), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
#Starting hyperparameters
UNITS = 10
NUM_BLOCKS = 1
TIME_STEP = 15
DROPOUT_RATE = 0.2
EPOCHS = 50
BATCH_SIZE = 32

# %%
def get_lstm(units, num_blocks, time_step, dropout_rate):
    lstm = Sequential()
    if num_blocks == 1:
        lstm.add(LSTM(units=units, activation="relu", input_shape=(time_step, 1)))
        lstm.add(Dropout(dropout_rate))
    else:
        for i in range(num_blocks):
            if i == 0:
                lstm.add(LSTM(units=units, activation="relu", return_sequences=True, input_shape=(time_step, 1)))
            elif i == NUM_BLOCKS - 1:
                lstm.add(LSTM(units=units, activation="relu"))
            else:
                lstm.add(LSTM(units=units, activation="relu", return_sequences=True))
            lstm.add(Dropout(dropout_rate))
    lstm.add(Dense(units = 1))

    lstm.compile(loss="mean_squared_error", optimizer="adam")
    return lstm

def train_and_eval_lstm(units = UNITS, num_blocks = NUM_BLOCKS, time_step = TIME_STEP, dropout_rate = DROPOUT_RATE,
               epochs = EPOCHS, batch_size = BATCH_SIZE, train_data = train_data, val_data = val_data):
    X_train, y_train = create_dataset(train_data, time_step)
    X_val, y_val = create_dataset(val_data, time_step)
    X_train = X_train[:, :, np.newaxis]
    X_val = X_val[:, :, np.newaxis]
    lstm = get_lstm(units, num_blocks, time_step, dropout_rate)
    lstm.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = epochs, batch_size = batch_size)
    original_y_val = scaler.inverse_transform(y_val.reshape(-1, 1))
    val_preds = lstm.predict(X_val)
    val_preds = scaler.inverse_transform(val_preds)
    return lstm, val_preds, original_y_val

# %%
units_lst = list(range(1, 21))
val_mae_lst = []
for units in units_lst:
    lstm, val_preds, original_y_val = train_and_eval_lstm(units = units)
    val_mae = mean_absolute_error(original_y_val, val_preds)
    val_mae_lst.append(val_mae)

# %%
sns.lineplot(x = units_lst, y = val_mae_lst)
plt.xlabel("Output shape of lstm layer")
plt.ylabel("Validation MAE")
# Out:
# Text(0, 0.5, 'Validation MAE')

# %%
tuned_units = units_lst[np.argmin(val_mae_lst)]
print(f"Minimum value is reached at {tuned_units} units")
# Out:
# Minimum value is reached at 19 units

# %%
time_step_lst = list(range(1, 21))
val_mae_lst = []
for time_step in time_step_lst:
    lstm, val_preds, original_y_val = train_and_eval_lstm(units = tuned_units, time_step = time_step)
    val_mae = mean_absolute_error(original_y_val, val_preds)
    val_mae_lst.append(val_mae)

# %%
sns.lineplot(x = time_step_lst, y = val_mae_lst)
plt.xlabel("Time step")
plt.ylabel("Validation MAE")
# Out:
# Text(0, 0.5, 'Validation MAE')

# %%
tuned_time_step = time_step_lst[np.argmin(val_mae_lst)]
print(f"Minimum value is reached at {tuned_time_step} time step")
# Out:
# Minimum value is reached at 7 time step

# %%
#Tuned hyperparameters
UNITS = tuned_units
NUM_BLOCKS = 1
TIME_STEP = tuned_time_step
DROPOUT_RATE = 0.2
EPOCHS = 50
BATCH_SIZE = 32

# %%
train_val_data = np.array(list(train_data.reshape(-1)) + list(val_data.reshape(-1))).reshape(-1, 1)

# %%
lstm, test_preds, original_y_test = train_and_eval_lstm(units = UNITS, num_blocks = NUM_BLOCKS, time_step = TIME_STEP, dropout_rate = DROPOUT_RATE,
                           epochs = EPOCHS, batch_size = BATCH_SIZE, train_data = train_val_data, val_data = test_data)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 2s 16ms/step - loss: 0.2294 - val_loss: 0.0261
# Epoch 2/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.1009 - val_loss: 0.0023
# Epoch 3/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0293 - val_loss: 0.0072
# Epoch 4/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0204 - val_loss: 0.0010
# Epoch 5/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 5.1944e-04
# Epoch 6/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0148 - val_loss: 4.5141e-04
# Epoch 7/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0136 - val_loss: 3.9282e-04
# Epoch 8/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0134 - val_loss: 3.9234e-04
# Epoch 9/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0134 - val_loss: 5.0386e-04
# Epoch 10/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 5.8904e-04
# Epoch 11/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0125 - val_loss: 5.0691e-04
# Epoch 12/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0132 - val_loss: 3.9754e-04
# Epoch 13/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 4.1954e-04
# Epoch 14/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0117 - val_loss: 3.7970e-04
# Epoch 15/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0117 - val_loss: 5.0762e-04
# Epoch 16/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 3.8038e-04
# Epoch 17/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 5.2984e-04
# Epoch 18/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 5.1977e-04
# Epoch 19/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 3.7243e-04
# Epoch 20/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 4.3881e-04
# Epoch 21/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 3.9537e-04
# Epoch 22/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 3.9680e-04
# Epoch 23/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 3.8748e-04
# Epoch 24/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0108 - val_loss: 7.7549e-04
# Epoch 25/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 4.1112e-04
# Epoch 26/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0112 - val_loss: 3.9548e-04
# Epoch 27/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 4.0331e-04
# Epoch 28/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 4.4245e-04
# Epoch 29/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 4.9969e-04
# Epoch 30/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 3.9681e-04
# Epoch 31/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 4.1104e-04
# Epoch 32/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 4.3713e-04
# Epoch 33/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 4.1221e-04
# Epoch 34/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0090 - val_loss: 4.9299e-04
# Epoch 35/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 4.0085e-04
# Epoch 36/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 4.2639e-04
# Epoch 37/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0097 - val_loss: 4.9117e-04
# Epoch 38/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0089 - val_loss: 5.0805e-04
# Epoch 39/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 3.8003e-04
# Epoch 40/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 3.7582e-04
# Epoch 41/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 3.8163e-04
# Epoch 42/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 3.9786e-04
# Epoch 43/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0078 - val_loss: 4.0495e-04
# Epoch 44/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 4.0667e-04
# Epoch 45/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 4.3949e-04
# Epoch 46/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 4.2415e-04
# Epoch 47/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0074 - val_loss: 4.1171e-04
# Epoch 48/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 3.9880e-04
# Epoch 49/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0080 - val_loss: 3.8113e-04
# Epoch 50/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 3.7728e-04
# 7/7 [==============================] - 0s 4ms/step

# %%
print("Test data MAE: ", mean_absolute_error(original_y_test, test_preds))
print("Test data RMSE: ", math.sqrt(mean_squared_error(original_y_test, test_preds)))
print("Test data R2 score:", r2_score(original_y_test, test_preds))
# Out:
# Test data MAE:  878.9092574097933
# Test data R2 score: 0.9235894162557963

# %%
lstm.save("lstm_model")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
# !zip -r lstm_model.zip lstm_model
# Out:
#   adding: lstm_model/ (stored 0%)
#   adding: lstm_model/variables/ (stored 0%)
#   adding: lstm_model/variables/variables.data-00000-of-00001 (deflated 40%)
#   adding: lstm_model/variables/variables.index (deflated 56%)
#   adding: lstm_model/assets/ (stored 0%)
#   adding: lstm_model/saved_model.pb (deflated 89%)
#   adding: lstm_model/keras_metadata.pb (deflated 86%)
#   adding: lstm_model/fingerprint.pb (stored 0%)

# %%
files.download("lstm_model.zip")

# %%
def load_data(coin, currency, limit):
    data = cryptocompare.get_historical_price_day(coin, currency, limit=limit)
    df = pd.DataFrame(data)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    return pd.DataFrame({"date": df['time'], "close": df["close"]})

def predict(model, data, future_days, time_step):
    '''
        Input: data: numpy array
        Output: price_predictions: numpy array of shape (future_days, 1)
    '''
    price_predictions = []
    temp_prices = data[-time_step:]
    for i in range(future_days):
        if type(model) == xgb.sklearn.XGBRegressor:
            price_prediction = model.predict(temp_prices.reshape(1, -1))[0]
        else:
            price_prediction = model.predict(temp_prices.reshape(1, -1, 1))[0][0]
        price_predictions.append(price_prediction)
        temp_prices = np.append(temp_prices, price_prediction)
        temp_prices = temp_prices[1:]
    price_predictions = np.array(price_predictions).reshape(-1, 1)
    return price_predictions

def preprocess(data):
    return scaler.transform(np.array(data).reshape(-1, 1)).reshape(1, -1)[0]

def postprocess(data):
    return scaler.inverse_transform(data).reshape(1, -1)[0]

def get_future_closes(model, data, future_days, time_step):
    today = data["date"].to_list()[-1]
    future_dates = [today + datetime.timedelta(days = i) for i in range(1, future_days + 1)]
    dates =  data["date"].to_list() + future_dates
    close_price = np.empty(len(dates))
    close_price[:] = np.nan
    close_price[:len(data["close"])] = data["close"]
    predicted_close = np.empty(len(dates))
    predicted_close[:] = np.nan
    price_predictions = predict(model, preprocess(data["close"]), future_days, time_step)
    price_predictions = postprocess(price_predictions)
    predicted_close[-future_days:] = price_predictions
    predicted_close[-future_days - 1] = close_price[-future_days - 1]
    return pd.DataFrame({"date": dates, "close": close_price, "predicted_close": predicted_close})

# %%
data = load_data("BTC", "USD", 200)
model = lstm
future_days = 20
future_closes = get_future_closes(model, data, future_days, TIME_STEP)
names = ["Close Price", "Predicted Close Price"]
names = cycle(names)
fig = px.line(future_closes,x=future_closes['date'], y=[future_closes['close'],future_closes['predicted_close']],
        labels={'value':'Close price','date': 'Date'})

fig.for_each_trace(lambda t:  t.update(name = next(names)))
fig.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="67b1728a-cf0c-4082-9205-388231c253a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67b1728a-cf0c-4082-9205-388231c253a9")) {                    Plotly.newPlot(                        "67b1728a-cf0c-4082-9205-388231c253a9",                        [{"hovertemplate":"variable=close<br>Date=%{x}<br>Close price=%{y}<extra></extra>","legendgroup":"close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close Price","orientation":"v","showlegend":true,"x":["2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00","2023-02-03T00:00:00","2023-02-04T00:00:00","2023-02-05T00:00:00","2023-02-06T00:00:00","2023-02-07T00:00:00","2023-02-08T00:00:00","2023-02-09T00:00:00","2023-02-10T00:00:00","2023-02-11T00:00:00","2023-02-12T00:00:00","2023-02-13T00:00:00","2023-02-14T00:00:00","2023-02-15T00:00:00","2023-02-16T00:00:00","2023-02-17T00:00:00","2023-02-18T00:00:00","2023-02-19T00:00:00","2023-02-20T00:00:00","2023-02-21T00:00:00","2023-02-22T00:00:00","2023-02-23T00:00:00","2023-02-24T00:00:00","2023-02-25T00:00:00","2023-02-26T00:00:00","2023-02-27T00:00:00","2023-02-28T00:00:00","2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-03-27T00:00:00","2023-03-28T00:00:00","2023-03-29T00:00:00","2023-03-30T00:00:00","2023-03-31T00:00:00","2023-04-01T00:00:00","2023-04-02T00:00:00","2023-04-03T00:00:00","2023-04-04T00:00:00","2023-04-05T00:00:00","2023-04-06T00:00:00","2023-04-07T00:00:00","2023-04-08T00:00:00","2023-04-09T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-15T00:00:00","2023-04-16T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19T00:00:00","2023-04-20T00:00:00","2023-04-21T00:00:00","2023-04-22T00:00:00","2023-04-23T00:00:00","2023-04-24T00:00:00","2023-04-25T00:00:00","2023-04-26T00:00:00","2023-04-27T00:00:00","2023-04-28T00:00:00","2023-04-29T00:00:00","2023-04-30T00:00:00","2023-05-01T00:00:00","2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-0 ...
